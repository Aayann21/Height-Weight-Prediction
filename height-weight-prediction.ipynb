# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_erro

# %%
url="/content/drive/MyDrive/heights.csv"
data=pd.read_csv(url)

# %%
print(data.head())
# Out:
#    height  weight
# 0   65.78  112.99
# 1   71.52  136.49
# 2   69.40  153.03
# 3   68.22  142.34
# 4   67.79  144.30

# %%
print(data.isnull().sum())
# Out:
# height    0
# weight    0
# dtype: int64

# %%
x=['height']
y=['weight']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(data[x],data[y],test_size=0.2,random_state=42)

# %%
model=LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
X_test.head()
# Out:
#      height
# 95    70.56
# 15    71.09
# 30    69.52
# 158   72.02
# 128   68.89
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['height'].plot(kind='hist', bins=20, title='height')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['height'].plot(kind='line', figsize=(8, 4), title='height')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
mse=mean_squared_error(Y_test,y_pred)
rmse=np.sqrt(mse)
r2=r2_score(Y_test,y_pred)
print("RMSE:", rmse)
print("R2 Score:", r2)
# Out:
# RMSE: 11.616501899549453
# R2 Score: 0.15370545335133745

# %%
plt.scatter(data['height'],data['weight'])
plt.xlabel('height')
plt.ylabel('weight')
plt.title('Height vs Weight')
plt.show()

# %%
plt.hist(data['height'], bins=10)
plt.xlabel('height')
plt.ylabel('frequency')
plt.title('Height Distribution')
plt.show()

# %%
plt.plot(data['height'], data['weight'], marker='o')
plt.xlabel('height')
plt.ylabel('weight')
plt.title('Height vs Weight')
plt.show()

# %%
sns.heatmap(data.corr(), annot=True)
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.violinplot(y=data['weight'])
plt.xlabel('Weight')
plt.title('Weight Distribution')
plt.show()

# %%
sns.pairplot(data)
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py'>
